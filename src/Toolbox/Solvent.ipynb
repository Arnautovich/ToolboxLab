# %%
def select_solvent(reaction_type, desired_properties):
    solvents = [
        {"name": "Water", "polarity": 9.0, "boiling_point": 100, "solubility": "Soluble"},
        {"name": "Ethanol", "polarity": 5.8, "boiling_point": 78.37, "solubility": "Soluble"},
        {"name": "Diethyl ether", "polarity": 1.9, "boiling_point": 34.6, "solubility": "Slightly soluble"},
        # Add more solvents with their properties
    ]

    scores = []

    for solvent in solvents:
        score = 0

        # Score based on polarity
        if abs(solvent["polarity"] - desired_properties["polarity"]) <= 2.0:
            score += 3

        # Score based on boiling point
        if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 10:
            score += 2

        # Score based on solubility
        if solvent["solubility"] == desired_properties["solubility"]:
            score += 1

        scores.append((solvent["name"], score))

    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
    return sorted_solvents

# Define desired properties
desired_properties = {"polarity": 5.5, "boiling_point": 70, "solubility": "Slightly soluble"}

# Call the function to get recommendations
recommendations = select_solvent("Grignard reaction", desired_properties)

# Print recommendations
print("Recommended solvents:")
for solvent, score in recommendations:
    print(f"{solvent}: Score - {score}")
# Out:
# Recommended solvents:
# Ethanol: Score - 5
# Diethyl ether: Score - 1
# Water: Score - 0

# %%
def select_solvent(reaction_type, desired_properties,criteteria):
    solvents = [
        {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity":0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity":0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity":0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether	", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 	56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67 },
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity":2.24},
        
        # Add more solvents with their properties
    ]
# viscosity in mPas
# Bp in ºC
#polarity by snyder
    scores = []

    for solvent in solvents:
        score = 0

        if criteria == "boiling_point_and_polarity":
            
        # Score based on polarity
            if abs(solvent["polarity"] - desired_properties["polarity"]) <= 0.5:
                score += 35
                break
            if abs(solvent["polarity"] - desired_properties["polarity"]) <= 1:
                score += 30
                break
            if abs(solvent["polarity"] - desired_properties["polarity"]) <= 8:
                score += 0
                break
            if abs(solvent["polarity"] - desired_properties["polarity"]) <= 7:
                score += 6
                break
            if abs(solvent["polarity"] - desired_properties["polarity"]) <= 5:
                score += 10
                break
            if abs(solvent["polarity"] - desired_properties["polarity"]) <= 3 :
                score += 15
                break
            if abs(solvent["polarity"] - desired_properties["polarity"]) <= 2:
                score += 25
                break
            
           
        
        # Score based on boiling point

            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 75:
                score += 0
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 50:
                score += 5
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 35:
                score += 10
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 20:
                score += 15
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 15:
                score += 25
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 10:
                score += 35
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 7:
                score += 40
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 5:
                score += 45
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 3:
                score += 55
                break
        if criteria == "boiling_point_and_viscosity":
        # Score based on viscosity
        
            if abs(solvent["viscosity"] - desired_properties["viscosity"]) <= 4:
                score += 0
                break
            if abs(solvent["viscosity"] - desired_properties["viscosity"]) <= 3.5:
                score += 3
                break
            if abs(solvent["viscosity"] - desired_properties["viscosity"]) <= 2.5:
                score += 5
                break
            if abs(solvent["viscosity"] - desired_properties["viscosity"]) <= 1.5 :
                score += 10
                break
            if abs(solvent["viscosity"] - desired_properties["viscosity"]) <= 1:
                score += 15
                break
            if abs(solvent["viscosity"] - desired_properties["viscosity"]) <= 0.5:
                score += 20
                break
            if abs(solvent["viscosity"] - desired_properties["viscosity"]) <= 0.2:
                score += 25
                break 
        # Score based on boiling point

            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 75:
                score += 0
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 50:
                score += 5
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 35:
                score += 10
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 20:
                score += 15
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 15:
                score += 25
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 10:
                score += 35
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 7:
                score += 40
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 5:
                score += 45
                break
            if abs(solvent["boiling_point"] - desired_properties["boiling_point"]) <= 3:
                score += 55
                break


        scores.append((solvent["name"], score))

    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
    return sorted_solvents

# Define desired properties
desired_properties = {"polarity": 5.5, "boiling_point": 70, "viscosity": 0.2}

# Call the function to get recommendations
 
recommendations = select_solvent("Grignard reaction", desired_properties, "boiling_point_and_polarity")


# Print recommendations
print("Recommended solvents:")
for solvent, score in recommendations:
    print(f"{solvent}: Score - {score}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 178>()
#     174 desired_properties = {"polarity": 5.5, "boiling_point": 70, "viscosity": 0.2}
#     176 # Call the function to get recommendations
# --> 178 recommendations = select_solvent("Grignard reaction", desired_properties, "boiling_point_and_polarity")
#     181 # Print recommendations
#     182 print("Recommended solvents:")
#
# Input In [20], in select_solvent(reaction_type, desired_properties, criteteria)
#      54 for solvent in solvents:
#      55     score = 0
# ---> 57     if criteria == "boiling_point_and_polarity":
#      58
#      59     # Score based on polarity
#      60         if abs(solvent["polarity"] - desired_properties["polarity"]) <= 0.5:
#      61             score += 35
#
# NameError: name 'criteria' is not defined

# %%
def select_solvent(reaction_type, desired_properties, criteria):
    solvents = [
        {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity":0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity":0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity":0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether	", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 	56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67 },
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity":2.24},
    ]

    # Define dictionaries for scores and thresholds for each property
    property_scores = {
        "polarity": {8: 0, 7: 6, 5: 10, 3: 15, 2: 25, 1: 30, 0.5: 35},
        "boiling_point": {75: 0, 50: 5, 35: 10, 20: 15, 15: 25, 10: 35, 7: 40, 5: 45, 3: 55},
        "viscosity": {4: 0, 3.5: 3, 2.5: 5, 1.5: 10, 1: 15, 0.5: 20, 0.2: 25}
    }

    scores = []
print (type(zs))
        for solvent in solvents:
            score = 0

        # Calculate score based on the selected criteria
        for property_name, thresholds in property_scores.v():
            desired_property = desired_properties.get(property_name, None)
            if desired_property is None:
                continue

            for key, value in property_scores():
                if abs(solvent[property_name] - desired_property) <= key:
                    score += value
                    break

        scores.append((solvent["name"], score))

    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
    return sorted_solvents

# Define desired properties
desired_properties = {"polarity": 5.5, "boiling_point": 70, "viscosity": 0.2}

# Call the function to get recommendations
recommendations = select_solvent("Grignard reaction", desired_properties, "boiling_point_and_polarity")

# Print recommendations
print("Recommended solvents:")
for solvent, score in recommendations:
    print(f"{solvent}: Score - {score}")
# Out:
#   File <tokenize>:73
#     sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# Définir un dictionnaire de valeurs
dictionnaire = {"a": 5, "b": 10, "c": 15, "d": 20}

# Définir une valeur seuil
seuil = 12

# Créer une liste des valeurs où la clé est supérieure au seuil
valeurs_sup_seuil = [valeur for valeur in dictionnaire.values() if valeur > seuil]

# Afficher le dictionnaire d'origine
print("Dictionnaire d'origine :", dictionnaire)

# Afficher la liste des valeurs supérieures au seuil
print("Valeurs supérieures au seuil de", seuil, ":", valeurs_sup_seuil)
# Out:
# Dictionnaire d'origine : {'a': 5, 'b': 10, 'c': 15, 'd': 20}
# Valeurs supérieures au seuil de 12 : [15, 20]

# %%
def select_solvent(reaction_type, desired_properties):
    solvents = [
        {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity":0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity":0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity":0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether	", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 	56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67 },
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity":2.24},
        # Add more solvents here
    ]

    # Define weights and thresholds in dictionaries
    weights = {
        "polarity": {0.5: 35, 1: 30, 2: 25, 3: 15, 5: 10, 7: 6, 8: 0},
        "boiling_point": {3: 55, 5: 45, 7: 40, 10: 35, 15: 25, 20: 15, 35: 10, 50: 5, 75: 0},
        "viscosity": {0.2: 25, 0.5: 20, 1: 15, 1.5: 10, 2.5: 5, 3.5: 3, 4: 0}
    }

    scores = []

    for solvent in solvents:
        score = 0

        # Calculate score for each criterion
        for prop, value in desired_properties.items():
            diff = abs(solvent[prop] - value)
            for threshold, weight in weights[prop].items():
                if diff <= threshold:
                    score += weight
                    break

        scores.append((solvent["name"], score))

    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
    return sorted_solvents

# Define desired properties
        
desired_properties = {"polarity": 3, "boiling_point": , "viscosity": 0.2}


# Call the function to get recommendations
recommendations = select_solvent("Grignard reaction", desired_properties)

# Print recommendations
print("Recommended solvents:")
for solvent, score in recommendations:
    print(f"{solvent}: Score - {score}")
# Out:
# Recommended solvents:
# Methanol: Score - 95
# Tetrahydrofuran: Score - 90
# Hexane: Score - 86
# Methyl Ethyl Ketone: Score - 85
# Acetone: Score - 85
# Acetonitrile: Score - 85
# Chloroform: Score - 80
# Ethyl Acetate: Score - 80
# Ethanol: Score - 75
# n-Butyl Chloride: Score - 65
# Methyl t-Butyl Ether	: Score - 65
# Ethylene Dichloride: Score - 65
# Methyl n-Propyl Ketone: Score - 60
# Isopropyl Alcohol: Score - 55
# Pyridine: Score - 55
# Methyl Isobutyl Ketone: Score - 50
# 1,4-Dioxane: Score - 50
# Cyclohexane: Score - 46
# Diethyl ether: Score - 45
# Ethyl Ether: Score - 45
# Dichloromethane: Score - 45
# N,N-Dimethylformamide: Score - 45
# Pentane: Score - 41
# Petroleum Ether: Score - 41
# n-Butyl Acetate: Score - 40
# Methyl Isoamyl Ketone: Score - 40
# n-Propyl Alcohol: Score - 40
# 2-Methoxyethanol: Score - 40
# Cyclopentane: Score - 36
# Heptane: Score - 36
# Iso-Octane: Score - 36
# Water: Score - 35
# Toluene: Score - 35
# Dimethyl Acetamide: Score - 35
# N-Methylpyrrolidone: Score - 35
# n-Butyl Alcohol: Score - 33
# Propylene Carbonate: Score - 33
# 1,1,2-Trichlorotrifluoroethane: Score - 31
# o-Xylene: Score - 30
# Chlorobenzene: Score - 30
# Isobutyl Alcohol: Score - 30
# Dimethyl Sulfoxide: Score - 30
# o-Dichlorobenzene: Score - 25

# %%
def select_solvent(reaction_type, desired_properties, criteria):
    solvents = [
        {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity":0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity":0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity":0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether	", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 	56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67 },
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity":2.24},
        # Add more solvents here
    ]

    # Define weights and thresholds in dictionaries
    weights = {
        "polarity": {0.5: 35, 1: 30, 2: 25, 3: 15, 5: 10, 7: 6, 8: 0},
        "boiling_point": {3: 55, 5: 45, 7: 40, 10: 35, 15: 25, 20: 15, 35: 10, 50: 5, 75: 0},
        "viscosity": {0.2: 25, 0.5: 20, 1: 15, 1.5: 10, 2.5: 5, 3.5: 3, 4: 0}
    }

    scores = []

    for solvent in solvents:
        score = 0

        # Calculate score for each criterion based on the desired combination
        if criteria == "boiling_point_and_polarity":
            for prop, value in desired_properties.items():
                diff = abs(solvent[prop] - value)
                for threshold, weight in weights[prop].items():
                    if diff <= threshold and (prop == "boiling_point" or prop == "polarity"):
                        score += weight
                        break
        elif criteria == "boiling_point_and_solubility":
            # Adjust this section based on the solubility criterion
            # Example: if solubility is represented by "solubility" property
            for prop, value in desired_properties.items():
                diff = abs(solvent[prop] - value)
                for threshold, weight in weights[prop].items():
                    if diff <= threshold and (prop == "boiling_point" or prop == "solubility"):
                        score += weight
                        break
        else:
            return "Invalid criteria"

        scores.append((solvent["name"], score))

    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
    return sorted_solvents

# Define desired properties
desired_properties = {"polarity": 5.5, "boiling_point": 70, "viscosity": 0.2}

# Define criteria
criteria = "boiling_point_and_viscosity"  # or "boiling_point_and_solubility"

# Call the function to get recommendations
recommendations = select_solvent("Grignard reaction", desired_properties, criteria )

# Print recommendations
print("Recommended solvents:")
for solvent, score in recommendations:
    print(f"{solvent}: Score - {score}")
# Out:
# Recommended solvents:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [24], in <cell line: 97>()
#      95 # Print recommendations
#      96 print("Recommended solvents:")
# ---> 97 for solvent, score in recommendations:
#      98     print(f"{solvent}: Score - {score}")
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
def select_solvent(reaction_type, boiling_point, polarity, viscosity, criteria):
    solvents = [
       {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity":0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity":0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity":0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 	56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67 },
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity":2.24},
    ]
    desired_properties = {"polarity": float(polarity), "boiling_point":float(boiling_point) , "viscosity":float(viscosity) }


    
    # Define weights and thresholds in dictionaries
    weights = {
        "polarity": {0.5: 35, 1: 30, 2: 25, 3: 15, 5: 10, 7: 6, 8: 0},
        "boiling_point": {3: 55, 5: 45, 7: 40, 10: 35, 15: 25, 20: 15, 35: 10, 50: 5, 75: 0},
        "viscosity": {0.2: 25, 0.5: 20, 1: 15, 1.5: 10, 2.5: 5, 3.5: 3, 4: 0}
    }

    scores = []

    for solvent in solvents:
        score = 0

        # Calculate score for each criterion based on the desired combination
        if criteria == "polarity":
            for prop, value in desired_properties.items():
                diff = abs(solvent[prop] - value)
                for threshold, weight in weights[prop].items():
                    if diff <= threshold and (prop == "boiling_point" or prop == "polarity"):
                        score += weight
                        break
        elif criteria == "viscosity":
            # Adjust this section based on the solubility criterion
            # Example: if solubility is represented by "solubility" property
            for prop, value in desired_properties.items():
                diff = abs(solvent[prop] - value)
                for threshold, weight in weights[prop].items():
                    if diff <= threshold and (prop == "boiling_point" or prop == "viscosity"):
                        score += weight
                        break
        else:
            return "Invalid criteria"

        scores.append((solvent["name"], score))  # Store both solvent name and score as a tuple

    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
    return sorted_solvents

# Define desired properties



# Call the function to get recommendations
recommendations = select_solvent("Grignard reaction", "150", "3", "1.2", "viscosity")

# Print recommendations
print("Recommended solvents:")
for solvent, score in recommendations:
    print(f"{solvent}: Score - {score}")
# Out:
# Recommended solvents:
# N,N-Dimethylformamide: Score - 75
# o-Xylene: Score - 60
# Methyl Isoamyl Ketone: Score - 60
# Chlorobenzene: Score - 35
# o-Dichlorobenzene: Score - 35
# Water: Score - 30
# n-Butyl Acetate: Score - 30
# 1,4-Dioxane: Score - 30
# Pyridine: Score - 30
# Dimethyl Acetamide: Score - 30
# Ethanol: Score - 25
# Cyclohexane: Score - 25
# Methyl Isobutyl Ketone: Score - 25
# 2-Methoxyethanol: Score - 25
# 1,1,2-Trichlorotrifluoroethane: Score - 20
# Toluene: Score - 20
# Ethylene Dichloride: Score - 20
# Methyl n-Propyl Ketone: Score - 20
# N-Methylpyrrolidone: Score - 20
# Diethyl ether: Score - 15
# Pentane: Score - 15
# Cyclopentane: Score - 15
# Heptane: Score - 15
# Hexane: Score - 15
# Iso-Octane: Score - 15
# Petroleum Ether: Score - 15
# n-Butyl Chloride: Score - 15
# Methyl t-Butyl Ether: Score - 15
# Ethyl Ether: Score - 15
# Dichloromethane: Score - 15
# n-Butyl Alcohol: Score - 15
# Tetrahydrofuran: Score - 15
# Chloroform: Score - 15
# Ethyl Acetate: Score - 15
# Methyl Ethyl Ketone: Score - 15
# Methanol: Score - 15
# Acetone: Score - 15
# Acetonitrile: Score - 15
# Dimethyl Sulfoxide: Score - 15
# Isopropyl Alcohol: Score - 10
# n-Propyl Alcohol: Score - 10
# Isobutyl Alcohol: Score - 8
# Propylene Carbonate: Score - 5

# %%
# Example of how to integrate the weights and thresholds for each reaction type into the solvent selection function

def select_solvent(reaction_type, boiling_point, polarity, viscosity):
    solvents = [
        {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity": 0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity": 0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity": 0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67},
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity": 2.24}
    ]

    desired_properties = {
        "polarity": float(polarity),
        "boiling_point": float(boiling_point),
        "viscosity": float(viscosity)
    }

    weights = {
        "polarity": {0.5: 40, 1: 35, 2: 30, 3: 25, 5: 20, 7: 15, 8: 10},
        "boiling_point": {3: 40, 5: 35, 7: 30, 10: 25, 15: 20, 20: 15, 35: 10, 50: 5, 75: 0},
        "viscosity": {0.2: 35, 0.5: 30, 1: 25, 1.5: 20, 2.5: 15, 3.5: 10, 4: 5}
    }

    reaction_adjustments = {
        "SN1": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "SN2": {"polarity": 1.4, "boiling_point": 1.5, "viscosity": 1.1},
        "Grignard": {"polarity": 1.4, "boiling_point": 1.5, "viscosity": 1.1},
        "Esterification": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Aldol": {"polarity": 1.5, "boiling_point": 1.2, "viscosity": 1.3},
        "Friedel-Crafts": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Hydrogenation": {"polarity": 1.1, "boiling_point": 1.3, "viscosity": 1.6},
        "Oxidation": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Reduction": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Heck": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Suzuki Coupling": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Sonogashira Coupling": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Nitration": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Sulfonation": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Amination": {"polarity": 1.3, "boiling_point": 1.2, "viscosity": 1.5},
        "Michael Addition": {"polarity": 1.5, "boiling_point": 1.2, "viscosity": 1.3},
        "Fischer Esterification": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Buchwald-Hartwig Amination:": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Grignard addition": {"polarity": 1.4, "boiling_point": 1.5, "viscosity": 1.1},
        "Wittig Reaction": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Claisen Condensation": {"polarity": 1.5, "boiling_point": 1.3, "viscosity": 1.2},
        "Cannizzaro Reaction": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Baeyer-Villiger Oxidation": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Polymerization": {"polarity": 1.2, "boiling_point": 1.3, "viscosity": 1.5},
        "Crystallization Reactions": {"polarity": 1.2, "boiling_point": 1.3, "viscosity": 1.5},
        "Enzymatic Reactions:": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.6},
        "Phase Transfer Catalysis:": {"polarity": 1.3, "boiling_point": 1.2, "viscosity": 1.5},
        "Reflux Reactions:": {"polarity": 1.2, "boiling_point": 1.7, "viscosity": 1.1},
        "Distillation": {"polarity": 1.1, "boiling_point": 1.8, "viscosity": 1.1},
        "Knoevenagel Condensation:": {"polarity": 1.2, "boiling_point": 1.6, "viscosity": 1.2},
        "Recrystallization::": {"polarity": 1.3, "boiling_point": 1.6, "viscosity": 1.1},
        "Steam Distillation:": {"polarity": 1.2, "boiling_point": 1.7, "viscosity": 1.1},
       
    }

    # Adjust weights based on the reaction type
    if reaction_type in reaction_adjustments:
        adjustments = reaction_adjustments[reaction_type]
        for key in weights:
            for threshold in weights[key]:
                weights[key][threshold] *= adjustments[key]

    # Calculate the scores for each solvent
    def calculate_score(solvent):
        score = 0
        for prop in desired_properties:
            value = solvent[prop]
            prop_weights = weights[prop]
            for threshold in sorted(prop_weights.keys()):
                if abs(desired_properties[prop] - value) <= threshold:
                    score += prop_weights[threshold]
                    break
        return score

    scores.append((solvent["name"], score))  # Store both solvent name and score as a tuple

    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)
    return sorted_solvents

    # Find the solvent with the highest score
    best_solvent = max(solvents, key=calculate_score)

    return best_solvent["name"]

# Example usage:
reaction_type = "SN2"
boiling_point = 50
polarity = 6
viscosity = 0.5

best_solvent = select_solvent(reaction_type, boiling_point, polarity, viscosity)
print(f"The best solvent for the {reaction_type} reaction is: {best_solvent}")
# Out:
# The best solvent for the SN2 reaction is: Acetone

# %%
def select_solvent(reaction_type, boiling_point, polarity, viscosity):
    solvents = [
        {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity": 0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity": 0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity": 0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67},
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity": 2.24}
    ]

    desired_properties = {
        "polarity": float(polarity),
        "boiling_point": float(boiling_point),
        "viscosity": float(viscosity)
    }

    weights = {
        "polarity": {0.5: 40, 1: 35, 2: 30, 3: 25, 5: 20, 7: 15, 8: 10},
        "boiling_point": {3: 40, 5: 35, 7: 30, 10: 25, 15: 20, 20: 15, 35: 10, 50: 5, 75: 0},
        "viscosity": {0.2: 35, 0.5: 30, 1: 25, 1.5: 20, 2.5: 15, 3.5: 10, 4: 5}
    }

    reaction_adjustments = {
        "SN1": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "SN2": {"polarity": 1.4, "boiling_point": 1.5, "viscosity": 1.1},
        "Grignard": {"polarity": 1.4, "boiling_point": 1.5, "viscosity": 1.1},
        "Esterification": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Aldol": {"polarity": 1.5, "boiling_point": 1.2, "viscosity": 1.3},
        "Friedel-Crafts": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Hydrogenation": {"polarity": 1.1, "boiling_point": 1.3, "viscosity": 1.6},
        "Oxidation": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Reduction": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Heck": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Suzuki Coupling": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Sonogashira Coupling": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Nitration": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Sulfonation": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Amination": {"polarity": 1.3, "boiling_point": 1.2, "viscosity": 1.5},
        "Michael Addition": {"polarity": 1.5, "boiling_point": 1.2, "viscosity": 1.3},
        "Fischer Esterification": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Buchwald-Hartwig Amination:": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Grignard addition": {"polarity": 1.4, "boiling_point": 1.5, "viscosity": 1.1},
        "Wittig Reaction": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Claisen Condensation": {"polarity": 1.5, "boiling_point": 1.3, "viscosity": 1.2},
        "Cannizzaro Reaction": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Baeyer-Villiger Oxidation": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.1},
        "Polymerization": {"polarity": 1.2, "boiling_point": 1.3, "viscosity": 1.5},
        "Crystallization Reactions": {"polarity": 1.2, "boiling_point": 1.3, "viscosity": 1.5},
        "Enzymatic Reactions:": {"polarity": 1.6, "boiling_point": 1.3, "viscosity": 1.6},
        "Phase Transfer Catalysis:": {"polarity": 1.3, "boiling_point": 1.2, "viscosity": 1.5},
        "Reflux Reactions:": {"polarity": 1.2, "boiling_point": 1.7, "viscosity": 1.1},
        "Distillation": {"polarity": 1.1, "boiling_point": 1.8, "viscosity": 1.1},
        "Knoevenagel Condensation:": {"polarity": 1.2, "boiling_point": 1.6, "viscosity": 1.2},
        "Recrystallization::": {"polarity": 1.3, "boiling_point": 1.6, "viscosity": 1.1},
        "Steam Distillation:": {"polarity": 1.2, "boiling_point": 1.7, "viscosity": 1.1},
       
    }
    
    if reaction_type in reaction_adjustments:
            adjustments = reaction_adjustments[reaction_type]
            for key in weights:
                for threshold in weights[key]:
                    weights[key][threshold] *= adjustments[key]

    scores = []

    for solvent in solvents:
        score = 0

        

        for prop, value in desired_properties.items():
            diff = abs(solvent[prop] - value)
            for threshold, weight in weights[prop].items():
                if diff <= threshold:
                    score += weight
                    break

        scores.append((solvent["name"], score))

    # Sort solvents based on scores
    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)

    return sorted_solvents[:5]

# Example usage:
reaction_type = "Distillation"
boiling_point = 90
polarity =5
viscosity = 2

top_solvents = select_solvent(reaction_type, boiling_point, polarity, viscosity)
print(f"The top 5 more accurate Solvents for the {reaction_type} reaction with the chosen values for Boiling point, polarity and viscosity are:")
for solvent, score in top_solvents:
    print(f"{solvent}: {score} points")
# Out:
# The top 5 more accurate Solvents for the Distillation reaction with the chosen values for Boiling point, polarity and viscosity are:
# n-Propyl Alcohol: 116.5 points
# Isopropyl Alcohol: 111.0 points
# Ethylene Dichloride: 109.0 points
# 1,4-Dioxane: 107.5 points
# Ethanol: 102.0 points

# %%
def select_solvent(reaction_type, boiling_point, polarity, viscosity):
    solvents = [
        {"name": "Water", "polarity": 10.2, "boiling_point": 100, "viscosity": 1.0},
        {"name": "Ethanol", "polarity": 4.3, "boiling_point": 78.37, "viscosity": 1.1},
        {"name": "Diethyl ether", "polarity": 2.8, "boiling_point": 34.6, "viscosity": 0.224},
        {"name": "Pentane", "polarity": 0.0, "boiling_point": 36.07, "viscosity": 0.23},
        {"name": "1,1,2-Trichlorotrifluoroethane", "polarity": 0.0, "boiling_point": 47.57, "viscosity": 0.71},
        {"name": "Cyclopentane", "polarity": 0.1, "boiling_point": 49.26, "viscosity": 0.44},
        {"name": "Heptane", "polarity": 0.1, "boiling_point": 98.43, "viscosity": 0.42},
        {"name": "Hexane", "polarity": 0.1, "boiling_point": 68.7, "viscosity": 0.31},
        {"name": "Iso-Octane", "polarity": 0.1, "boiling_point": 99.24, "viscosity": 0.50},
        {"name": "Petroleum Ether", "polarity": 0.1, "boiling_point": 50, "viscosity": 0.46},
        {"name": "Cyclohexane", "polarity": 0.2, "boiling_point": 80.72, "viscosity": 1.0},
        {"name": "n-Butyl Chloride", "polarity": 1.0, "boiling_point": 78.44, "viscosity": 0.45},
        {"name": "Toluene", "polarity": 2.4, "boiling_point": 110.62, "viscosity": 0.59},
        {"name": "Methyl t-Butyl Ether", "polarity": 2.5, "boiling_point": 55.2, "viscosity": 0.27},
        {"name": "o-Xylene", "polarity": 2.5, "boiling_point": 144.41, "viscosity": 0.81},
        {"name": "Chlorobenzene", "polarity": 2.7, "boiling_point": 131.69, "viscosity": 0.80},
        {"name": "o-Dichlorobenzene", "polarity": 2.7, "boiling_point": 180.48, "viscosity": 1.32},
        {"name": "Ethyl Ether", "polarity": 2.8, "boiling_point": 34.55, "viscosity": 0.24},
        {"name": "Dichloromethane", "polarity": 3.1, "boiling_point": 39.75, "viscosity": 0.44},
        {"name": "Ethylene Dichloride", "polarity": 3.5, "boiling_point": 83.48, "viscosity": 0.79},
        {"name": "n-Butyl Alcohol", "polarity": 3.9, "boiling_point": 117.5, "viscosity": 2.98},
        {"name": "Isopropyl Alcohol", "polarity": 3.9, "boiling_point": 82.26, "viscosity": 2.4},
        {"name": "n-Butyl Acetate", "polarity": 4.0, "boiling_point": 126.11, "viscosity": 0.74},
        {"name": "Isobutyl Alcohol", "polarity": 4.0, "boiling_point": 108, "viscosity": 3.95},
        {"name": "Methyl Isoamyl Ketone", "polarity": 4.0, "boiling_point": 144.9, "viscosity": 0.8},
        {"name": "n-Propyl Alcohol", "polarity": 4.0, "boiling_point": 97.20, "viscosity": 2.3},
        {"name": "Tetrahydrofuran", "polarity": 4.0, "boiling_point": 66, "viscosity": 0.55},
        {"name": "Chloroform", "polarity": 4.1, "boiling_point": 61.15, "viscosity": 0.57},
        {"name": "Methyl Isobutyl Ketone", "polarity": 4.2, "boiling_point": 117.4, "viscosity": 0.58},
        {"name": "Ethyl Acetate", "polarity": 4.4, "boiling_point": 77.11, "viscosity": 0.45},
        {"name": "Methyl n-Propyl Ketone", "polarity": 4.5, "boiling_point": 102.4, "viscosity": 0.51},
        {"name": "Methyl Ethyl Ketone", "polarity": 4.7, "boiling_point": 79.64, "viscosity": 0.43},
        {"name": "1,4-Dioxane", "polarity": 4.8, "boiling_point": 101.32, "viscosity": 1.37},
        {"name": "Methanol", "polarity": 5.1, "boiling_point": 64.7, "viscosity": 0.59},
        {"name": "Acetone", "polarity": 5.1, "boiling_point": 56.29, "viscosity": 0.36},
        {"name": "Pyridine", "polarity": 5.3, "boiling_point": 115.25, "viscosity": 0.95},
        {"name": "2-Methoxyethanol", "polarity": 5.5, "boiling_point": 124, "viscosity": 1.72},
        {"name": "Acetonitrile", "polarity": 5.8, "boiling_point": 81.60, "viscosity": 0.38},
        {"name": "Propylene Carbonate", "polarity": 6.1, "boiling_point": 241.7, "viscosity": 2.76},
        {"name": "N,N-Dimethylformamide", "polarity": 6.4, "boiling_point": 153.0, "viscosity": 0.92},
        {"name": "Dimethyl Acetamide", "polarity": 6.5, "boiling_point": 166.1, "viscosity": 2.14},
        {"name": "N-Methylpyrrolidone", "polarity": 6.7, "boiling_point": 202, "viscosity": 1.67},
        {"name": "Dimethyl Sulfoxide", "polarity": 7.2, "boiling_point": 189.0, "viscosity": 2.24}
    ]

    desired_properties = {
        "polarity": float(polarity),
        "boiling_point": float(boiling_point),
        "viscosity": float(viscosity)
    }

    weights = {
        "polarity": {0.5: 40, 1: 35, 2: 30, 3: 25, 5: 20, 7: 15, 8: 10},
        "boiling_point": {3: 40, 5: 35, 7: 30, 10: 25, 15: 20, 20: 15, 35: 10, 50: 5, 75: 0},
        "viscosity": {0.2: 35, 0.5: 30, 1: 25, 1.5: 20, 2.5: 15, 3.5: 10, 4: 5}
    }

    reaction_adjustments = {
        "SN1": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "SN2": {"polarity": 0.4, "boiling_point": 0.5, "viscosity": 0.1},
        "Grignard": {"polarity": 0.4, "boiling_point": 0.5, "viscosity": 0.1},
        "Esterification": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Aldol": {"polarity": 0.5, "boiling_point": 0.2, "viscosity": 0.3},
        "Friedel-Crafts": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Hydrogenation": {"polarity": 0.1, "boiling_point": 0.3, "viscosity": 0.6},
        "Oxidation": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Reduction": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Heck": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Suzuki Coupling": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Sonogashira Coupling": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Nitration": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Sulfonation": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Amination": {"polarity": 0.3, "boiling_point": 0.2, "viscosity": 0.5},
        "Michael Addition": {"polarity": 0.5, "boiling_point": 0.2, "viscosity": 0.3},
        "Fischer Esterification": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Buchwald-Hartwig Amination": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Grignard addition": {"polarity": 0.4, "boiling_point": 0.5, "viscosity": 0.1},
        "Wittig Reaction": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Claisen Condensation": {"polarity": 0.5, "boiling_point": 0.3, "viscosity": 0.2},
        "Cannizzaro Reaction": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Baeyer-Villiger Oxidation": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.1},
        "Polymerization": {"polarity": 0.2, "boiling_point": 0.3, "viscosity": 0.5},
        "Crystallization Reactions": {"polarity": 0.2, "boiling_point": 0.3, "viscosity": 0.5},
        "Enzymatic Reactions": {"polarity": 0.6, "boiling_point": 0.3, "viscosity": 0.6},
        "Phase Transfer Catalysis": {"polarity": 0.3, "boiling_point": 0.2, "viscosity": 0.5},
        "Reflux Reactions": {"polarity": 0.2, "boiling_point": 0.7, "viscosity": 0.1},
        "Distillation": {"polarity": 0.1, "boiling_point": 0.8, "viscosity": 0.1},
        "Knoevenagel Condensation": {"polarity": 0.2, "boiling_point": 0.6, "viscosity": 0.2},
        "Recrystallization": {"polarity": 0.3, "boiling_point": 0.6, "viscosity": 0.1},
        "Steam Distillation": {"polarity": 0.2, "boiling_point": 0.7, "viscosity": 0.1},
    }
    
    if reaction_type in reaction_adjustments:
            adjustments = reaction_adjustments[reaction_type]
            for key in weights:
                for threshold in weights[key]:
                    weights[key][threshold] *= adjustments[key]

    scores = []

    for solvent in solvents:
        score = 0

        

        for prop, value in desired_properties.items():
            diff = abs(solvent[prop] - value)
            for threshold, weight in weights[prop].items():
                if diff <= threshold:
                    score += weight
                    break

        scores.append((solvent["name"], score))

    # Sort solvents based on scores
    sorted_solvents = sorted(scores, key=lambda x: x[1], reverse=True)

    return sorted_solvents[:5]

# Example usage:
reaction_type = "Distillation"
boiling_point = 90
polarity = 5
viscosity = 2

top_solvents = select_solvent(reaction_type, boiling_point, polarity, viscosity)
print(f"The top 5 more accurate Solvents for the {reaction_type} reaction with the chosen values for Boiling point, polarity and viscosity are:")
for solvent, score in top_solvents:
    print(f"{solvent}: {score} points")
# Out:
# The top 5 more accurate Solvents for the Distillation reaction with the chosen values for Boiling point, polarity and viscosity are:
# Ethylene Dichloride: 29.0 points
# n-Propyl Alcohol: 26.5 points
# Isopropyl Alcohol: 26.0 points
# Acetonitrile: 25.0 points
# Cyclohexane: 24.5 points
